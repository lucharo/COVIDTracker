# %%
import pandas as pd

# %%
df=pd.read_csv("SomeKeywords.csv")

# %%
# !pip freeze
# Out:
# alabaster==0.7.12
# applaunchservices==0.2.1
# appnope==0.1.0
# astroid==2.3.3
# atomicwrites==1.3.0
# attrs==19.3.0
# autopep8==1.5
# Babel==2.8.0
# backcall==0.1.0
# bleach==3.1.0
# certifi==2019.11.28
# chardet==3.0.4
# cloudpickle==1.2.2
# cycler==0.10.0
# Cython==0.29.16
# decorator==4.4.1
# defusedxml==0.6.0
# diff-match-patch==20181111
# dill==0.3.1.1
# docutils==0.16
# entrypoints==0.3
# flake8==3.7.9
# graphviz==0.13.2
# hdbscan==0.8.26
# helpdev==0.6.10
# idna==2.8
# imageio==2.6.1
# imagesize==1.2.0
# importlib-metadata==1.4.0
# intervaltree==3.0.2
# ipykernel==5.1.3
# ipython==7.11.1
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# isort==4.3.21
# jedi==0.14.1
# Jinja2==2.10.3
# joblib==0.14.1
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==6.0.0
# jupyter-core==4.6.1
# keyring==21.1.0
# kiwisolver==1.1.0
# lazy-object-proxy==1.4.3
# MarkupSafe==1.1.1
# matplotlib==3.1.1
# mccabe==0.6.1
# mistune==0.8.4
# more-itertools==8.1.0
# ...

# %%
# !source ../tweetCOVID/bin/activate

# %%
# !pwd
# Out:
# /Users/anaraquelpengelly/Desktop/Coro/COVIDTracker/TweetSearch/BackSearch

# %%
# !cd ..

# %%
# !pwd
# Out:
# /Users/anaraquelpengelly/Desktop/Coro/COVIDTracker/TweetSearch/BackSearch
